# %%
recipeName = '베이컨 토마토 샌드위치'
filename = '1.jpg'
process = '1. 기름없는 팬에 베이컨을 약불에서 바삭하게 구워주세요.$ 2. 팬에 베이컨 기름을 버리지 말고 계란프라이를 해주세요. 후추로 약간 간을 해주세요.$ 3.양상추는 깨끗하게 씻어서 빵크기에 맞게 손으로 뜯어 물기 제거까지 해주세요. 토마토는 슬라이스 해주세요.$ 4. 식빵은 기름없이 팬에 구워주세요.$ 5. 식빵 양 쪽에 머스터드로 소스를 발라주세요.$ 6. 빵 위에 양상추, 토마토, 계란프라이, 베이컨, 치즈를 올려주세요.'
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '몬테크리스토'
filename = '2.jpg'
process = '1. 식빵테두리를 잘라주세요.$ 2. 식빵 한 장 놓고 그 위에 머스타드를 펴 바르고 그 위에 슬라이스햄, 슬라이스치즈 순으로 올려주세요.$ 3. 다른 식빵 하나에 쨈을 발라서 쨈 바른 부위가 슬라이스치즈 쪽으로 가게 올려주세요.$ 4. 그 위에 또다시 쨈을 바르고 슬라이스치즈와 슬라이스햄을 올려주세요.$ 5. 또 다른 식빵에 머스타드를 펴 바르고 머스타드 바른 쪽을 슬라이스햄 쪽으로 덮어주세요.$ 6. 계란에 소금 한 꼬집 넣고 계란을 잘 풀어주세요.$ 7. 토스트에 계란물을 잘 입혀 주세요.$ 8. 프라이팬에 기름을 두르고 약불에서 골고루 익혀주세요.' 
recipeTime = '15분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '프렌치 토스트'
filename = '3.jpg'
process = '1. 그릇에 계란, 소금을 1꼬집 넣어 잘 풀어줍니다.$ 2. 설탕, 우유를 넣어 잘 섞어 줍니다.$ 3. 식빵 3장의 끝부분을 최대한 얇게 잘라줍니다.$ 4. 용기에 자른 식빵을 넣어줍니다.$ 5. 만들어 둔 계란물을 부어 빵이 계란물을 모두 흡수 할 수 있도록 해둡니다.$ 6. 팬에 버터를 녹여줍니다.$ 7. 뚜껑을 덮어 10분간 구워줍니다.$ 8. 뒤집어서 또 10분간 구워줍니다.'
recipeTime = '15분'
difficulty = 'easy'
Classification = '유제품'
method = '부침'

# %%
recipeName = '토마토 달걀 볶음'
filename = '4.jpg'
process = '1. 먼저 쪽파는 송송 썰어 고명으로 준비 해 주시고 토마토는 크기에 따라 4~8등분해서 준비할게요.$ 2. 달걀 3개에 우유 두 큰술 정도 넣고 간은 1/2티스푼 정도로 살짝 해 주세요. 잘 섞어서 준비할게요.$ 3. 프라이팬을 중불에서 3분간 예열 후 버터를 반큰술 넣고 녹인다음 토마토를 앞뒤로 살짝 구울게요. 이때 소금으로 약간 간 해 주시면 더욱 좋습니다. 굳이 색이 날 정도로 구우실 필요는 없습니다.$ 4. 이제 풀어 둔 달걀을 넣어줄게요.$ 5. 아주 빠르게 저어 주실 필요는 없지만 천천히 잘 섞어가며 볶듯이 조리 해 주세요. 너무 자주 자주 뒤적거리면 토마토가 다 으깨어져서 요리가 지저분 해 질 수 있으니 주의 해 주세요.$ 6. 마지막으로 후추 약간과 송송 썬 쪽파를 곁들여 주시면 간단한 아침메뉴로 좋은 토마토 달걀 볶음 완성되었습니다.'
recipeTime = '10분'
difficulty = 'normal'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '부대찌개'
filename = '5.jpg'
process = '1. 고추는 어슷썰고 두부는 한입크기로 썰어주세요.$ 2. 스팸은 반드시 얇게 잘라주세요. 두꺼우면 국물 맛이 제대로 안 배고 맛이 따로 놀아요. 비엔나는 사선으로 잘라주세요.$ 3. 떡은 너무 많이 넣으면 국물이 텁텁해지므로 반드시 1줌만 넣어주세요.$ 4. 김치도 많이 넣으면 김치맛이 많이 나요. 적당한 밸런스가 중요한데요. 밥공기 1/4 넣어주세요.$ 5. 된장반큰술,고추가루 4큰술(듬뿍), 마늘2큰술, 국간장2큰술, 설탕반큰술, 물 소주컵 반컵을 섞어주세요.$6. 두부, 햄, 떡을 테두리에 두르고 김치는 가운데 넣어주세요.$7. 양념장 올리고 사골곰탕 육수를 1봉지 붓고 물 보충을 해주세요.$9. 대파와 청양고추 홍고추 모두 올려주세요.$10. 이제 팔팔 끓입니다.'
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '끓이기'

# %%
recipeName = '버섯잡채'
filename = '6.jpg'
process = '1. 느타리버섯은 가닥가닥 떼어주고 새송이, 표고버섯은 길게 썰어 주고 양파, 당근, 파프리카는 채썰어주세요.$2. 물이 팔팔 끓기 시작하면 당면을 넣고 6분간 삶아 줍니다.$3. 삶아진 당면은 찬물에 헹궈주고 체에 밭쳐 탈탈 털어 물기를 제거해 주세요.$4. 팬에 식용유 5숟가락, 간장 50ml, 올리고 당 100ml를 넣어 양념장을 만들어 주세요.$5. 센 불에서 양념장이 끓기 시작하면 삶아놓은 당면을 넣고 양념장이 자작 자작하기 시작하면서 물기가 사라질 때까지 볶아주세요.$6. 재료를 각각 볶아주세요. 간은 소금으로 살짝 해주었어요.$7. 양념해 놓은 당면에 볶아 놓은 버섯, 당근, 양파, 파프리카를 한데 넣고 참기름 2, 통깨 0.5를 넣어주고 재료를 고루 버무려 주세요.'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '김치볶음밥'
filename = '7.jpg'
process = '1. 달군팬에 기름을 두르고 중약불에서 대파랑 다진마늘을 볶아주세요.$' + \
        '2. 햄을 썰어 넣고 살짝 더 볶아주세요.$' + \
        '3. 김치 많이많이 송송 썰어 넣어주세요. 김치가 탈 수 있으니 약불로 줄여주세요.$' + \
        '4. 설탕 1숟가락, 간장 1숟가락을 넣어주세요.$' + \
        '5. 고추장 반스푼을 넣고 볶아주세요.$' + \
        '6. 밥을 넣고 양념이 배이도록 볶아주세요$' + \
        '7. 후춧가루 톡톡! 참기름 빙~ 둘러주고 통깨 뿌려주면 완성!$'
recipeTime = '20분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '햄계란볶음밥'
filename = '8.jpg'
process = '1. 햄은 1/2개를 반 자르고 얇게 사각썰기 한 후 다지듯이 작은 큐브썰기로 한다.$' + \
        '2. 후라이팬에 들기름2T 두르고 햄을 담는다.$' + \
        '3. 가스레인지불은 중센불로 5분간 햄을 볶는다.$' + \
        '4. 밥을 넣는다.$' + \
        '5. 달걀 한 개를 깨트려 넣고 진간장1~2t를 넣는다.$' + \
        '6. 계란이 풀어져서 간장밥과 햄이 고루 잘 섞이도록 중센불에서 중약불로 5~10분 고슬고슬 하게 볶는다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '육류'
method = '볶음'

# %%
recipeName = '비빔밥'
filename = '9.jpg'
process = '1. 양파, 당근, 애호박을 채썰어서 준비합니다.$' + \
        '2. 고추장 2T +간장 2T+설탕 1.5T+깨소금, 참기름 +식초 1T를 넣고 잘섞어 양념장을 만듭니다.$' + \
        '3. 먼저 당근을 소금 1꼬집 넣고 색깔이 나게 볶아줍니다.$' + \
        '4. 애호박도 소금 1꼬집 넣고 볶아줍니다.$' + \
        '5. 양파는 간장 1T 넣고 중불에 볶아줍니다. 꽤 오래 볶아서 단맛이 나게 볶아줍니다.$' + \
        '6. 소금, 후추로 밑간해 놓은 채썰어준 돼지고기를 볶아줍니다.$' + \
        '7. 익은 돼지고기를 아까 만들어 놓은 양념장과 섞어 줍니다.$' + \
        '8. 따뜻한 밥위에 볶아 놓은 야채를 올리고 반숙 계란 후라이, 양념장을 크게 1T 떠서 셋팅하면 비빔밥 완성!$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '비빔'

# %%
recipeName = '야채튀김'
filename = '10.jpg'
process = '1. 감자는 껍질 제거하고 최대한 얇게, 나머지 재료는 0.2~0.3cm 두께로 채썰기$' + \
        '2. 채썬 재료와 소금, 튀김가루, 물 넣어 잘 섞기$' + \
        '3. 고르게 섞이면 팬에 기름 넉넉히 두르고 한숟가락씩 떠 넣어 앞뒤 노릇하게 튀기기$' + \
        '4. 프라이팬에 재료가 반쯤 잠길정도의 기름을 넣고 진행해요. 기름을 조금 두르고 부치면 야채전이돼요.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '튀김'

# %%
recipeName = '오이미역냉국'
filename = '11.jpg'
process = '1. 미역은 물에 살짝 불렸다가 빡빡 문질러 씻어주세요.$' + \
        '2. 먹기 좋은 크기로 썰어서 준비하세요.$' + \
        '3. 볼에 오이도 굵은 소금이나 베이킹 소다로 깨끗하게 씻은 후, 칼등으로 오이돌기를 긁어내세요.$' + \
        '4. 그리고 채를 썰어서 준비하세요.$' + \
        '5. 양파도 얇게 채를 썰어서 물에 담궈 아린맛을 제거해 주세요.$' + \
        '6. 물 600ml, 소금 1큰술, 설탕 4큰술, 식초 6큰술을 넣어 녹을 수 있도록 잘 저어주세요.$' + \
        '7. 채를 썬 오이와 양파를 넣어주세요. 얼음, 미역은 먹기전에 넣어주시는 게 식감도 있고 좋아요$' + \
        '8. 마지막에 국물과 통깨, 청양고추를 넣어 주세요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '기타'

# %%
recipeName = '버섯불고기'
filename = '12.jpg'
process = '1. 소고기는 적당한 크기로 썰어서 볼에 담고, 설탕과 매실액기스를 넣어서 조물조물 해서 10분간 재워두세요.$' + \
        '2. 간장 4Ts, 다진마늘 1+1/2Ts, 참기름 1+1/3Ts, 후춧가루 넣어서 잘 섞어두세요. 소고기에 양념이 베이는 동안 다른 재료 준비를 하면 좋아요.$' + \
        '3. 새송이버섯은 길게 반 잘라서 먹기좋은 크기로 썰어주고, 팽이버섯은 밑둥을 잘라 씻어서 준비합니다.$' + \
        '4. 양파는 채 썰어주고, 대파도 어슷썰어서 준비해주세요.$' + \
        '5. 양념을 해둔지 20분정도 지나면 소고기를 냄비에 넣고 중약불에 올려주세요.$' + \
        '6. 고기가 어느정도 익으면 새송이버섯, 대파, 양파를 넣어서 한번 섞어주고 뚜껑을 닫아 중불에서 익혀줍니다.$' + \
        '7. 재료들이 다 익고 양념이 어느정도 베이면 마지막으로 팽이버섯을 넣어서 한번 끓여주면 완성입니다.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '육류'
method = '끓이기'

# %%
recipeName = '해물부추부침개'
filename = '13.jpg'
process = '1. 잘씻은 부추는 엄지손가락 길이정도로 잘라주세요.$' + \
        '2. 양파는 얇게 채썰어주세요.또는 집에 있는 야채들을 채썰어 넣어도 좋아요.$' + \
        '3. 깐홍합은 물로 살살씻어 키친타올에 올려 물기를 제거해주세요. 새우나 조갯살 넣어도 좋아요.$' + \
        '4. 오징어는 가늘게 채썰어 끓는물에 살짝 데쳐서 준비해주세요.$' + \
        '5. 부침가루, 튀김가루를 섞을땐 꼭 차가운물로 해야 더욱 바삭바삭해요. 이때 전분가루를 소량 넣으면 더 바삭거려요.$' + \
        '6. 모두 섞어주세요. 중불에 기름을 넉넉히 두르고 얇게 올려주세요$' + \
        '7. 다올리고나서 가운데를 젓가락으로 빙글빙글 뚫어주세요. 뚫은곳에 식용유를 살짝 더넣어주세요.$' + \
        '8. 후라이팬을 살짝 기울였을때 부침개가 잘움직이면 뒤집어 주세요.$' + \
        '9. 뒤집어준후 테두리부분에 살짝 기름을 더둘러주세요.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '해산물'
method = '부침'

# %%
recipeName = '쪽파숙회'
filename = '14.jpg'
process = '1. 우선 쪽파른 손질해서 여러번 헹구어서 물기를 빼서 준비해주세요.$' + \
        '2. 물이 끓기 시작하면 쪽파의 흰 밑둥부분을 먼저 잠시 담가 주세요.$' + \
        '3. 그 다음 위 잎부분까지 넣어서 살짝만 데쳐 주세요.$' + \
        '4. 쪽파 데치는 시간은 30초-1분 이내로 해주세요.$' + \
        '5. 쪽파를 찬물에 헹구어서 물기를 꽉 짜주세요.$' + \
        '6. 쪽파 1개나 2개를 한입에 먹기 좋은 크기로 돌돌 말아 주세요.$' + \
        '7. 접시에 담아 초장에 찍어 먹으세요.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '데치기'

# %%
recipeName = '가지탕수육'
filename = '15.jpg'
process = '1. 가지는 꼭지 부분의 껍질을 벗겨 뭉뚝하게 썰어주세요.$' + \
        '2. 파프리카와 양파도 비슷한 크기로 썰어주세요. $' + \
        '3. 소스를 케첩 4스푼, 굴 소스 2스푼, 설탕 1스푼, 올리고당 1스푼 반, 식초 1스푼,참기름 반 스푼, 통깨 약간을 작은 볼에 넣고 골고루 섞어 만들어 주세요.$' + \
        '4. 튀김가루 종이컵 한 컵(75g), 물 종이컵 반컵 큰 볼에 넣고 덩어리가 생기지 않게만 가볍게 저어 주시며 섞어주세요.$' + \
        '5. 손질해놓은 가지는 물기를 제거한 후 위생 봉지 안에 튀김가루 5스푼과 썰어 놓은 가지를 넣고 흔들어 주세요.$' + \
        '6. 움푹 팬 프라이팬에 식용유를 채우고 중불로 예열을 시작해주세요.$' + \
        '7. 튀김가루로 골고루 묻혀놓은 가지는 가볍게 털어주신 후 튀김옷에 퐁당!$' + \
        '8. 튀김옷을 살짝 기름에 던져 넣고 3초 후 떠오르면 튀기기 적당한 온도에요.$' + \
        '9. 서로 붙지 않게 하나씩 넣어 주시고 중.약불에서 3분 정도 노릇하게 튀겨 주세요.$' + \
        '10. 움푹 팬 프라이팬에 식용유 3스푼을 넣고 중불로 예열해주세요.$' + \
        '11. 소스를 붓고, 끓어오르면 가지 튀김을 넣어 소스가 튀김 전체에 묻도록 가볍게 버무려주시면 됩니다.$' + \
        '12. 파프리카와 양파를 모두 넣어 중불에서 1분 정도 가볍게 버무려주세요.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '채소류'
method = '튀김'

# %%
recipeName = '돼지갈비찜'
filename = '16.jpg'
process = '1. 돼지고기를 물에 담궈 핏물을 빼줍니다.$' + \
        '2. 대파,양파,청양고추를 큼직하게 썰어줍니다.$' + \
        '3. 고추장,고추가루,간장,다진마늘,설탕,올리고당,후추,참기름을 넣고 잘 섞어줍니다.$' + \
        '4. 핏기를 뺀 돼지고기를 끓는물에 5분정도 삶아주세요.$' + \
        '5. 삶은 돼지갈비를 채에 받친 후 물로 씻어주세요	.$' + \
        '6. 냄비에 삶은 돼지갈비,양념장,청양고추를 넣은 다음 돼지갈비가 푹 잠기게 물을 넣어주세요.$' + \
        '7. 센불에서 물이 팔팔 끓을때까지 두신 후 팔팔 끓기 시작하면 뚜껑을 덮고 중불에서 20분간 끓여주세요.$' + \
        '8. 감자를 넣고 10분간 삶아주세요.$' + \
        '9. 대파와 양파를 넣고 5~10분정도 더 삶아주세요.$' + \
        '10. 물이 적당히 쫄아 들면 완성입니다.$'
recipeTime = '90분'
difficulty = 'normal'
Classification = '육류'
method = '찜'

# %%
recipeName = '계란감자국'
filename = '17.jpg'
process = '1. 흐르는 물에 사방 10cm 다시마 한장을 씻으세요.$' + \
        '2. 냄비에 물 8컵, 멸치 한줌, 다시마 한장을 넣고 끓이세요.$' + \
        '3. 10분간 끓인 후 건더기는 모두 건져 내세요.$' + \
        '4. 냄비에 멸치, 다시마 끓인 물 4컵을 부어 줍니다.$' + \
        '5. 감자를 껍질 벗겨 0.5cm 두께로 부채모양으로 잘라 줍니다. 대파 1대를 어슷하게 썰어 줍니다.$' + \
        '6. 냄비에 준비한 감자와 대파 흰부분을 먼저 넣고 함께 끓여 줍니다. 거품은 모두 걷어 줍니다.$' + \
        '7. 국간장 1큰술로 간을 해 줍니다.$' + \
        '8. 계란 1개를 알끈이 없도록 풀어 끓는 국물에 크게 휘~ 둘러가며 부어 줍니다.$' + \
        '9. 대파 초록부분을 넣고 끓인 후 부족한 간은 소금, 후추약간으로 해 줍니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '끓이기'

# %%
recipeName = '새송이버섯 간장버터구이'
filename = '18.jpg'
process = '1. 먼저 새송이 버섯 3동은 밑동을 제거하고 일정한 두께로 잘라 줍니다. 대파와 청양고추는 작게 썰어 줍니다.$' + \
        '2. 간장5T,올리고당2T,물2T,다진마늘1T, 참기름1T를 섞어주신뒤 썰어놓은 청양고추,대파를 섞어줍니다.$' + \
        '3. 달궈진 팬에 버터 1스푼 녹여준 뒤 새송이버섯을 앞뒤로 중약불로 구워 줍니다.$' + \
        '4. 버섯이 쫄깃하게 구워지면 만들어 놓은 양념을 버섯이 자작히 잠기도록 부어 줍니다.$' + \
        '5. 약불에서 타지 않게 졸여 주면 됩니다.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '굽기'

# %%
recipeName = '오이토마토무침'
filename = '19.jpg'
process = '1. 오이와 토마토는 깨끗이 씻어 주고, 오이 표면에 있는 오돌도톨한 살짝 제거 해 주세요.$' + \
        '2. 오이는 반으로 잘라서 씨를 제거 한 뒤 1.5cm 정도로 썰어 주세요.$' + \
        '3. 꽃소금 약간 넣어 섞어 준 다음 10분간 절이세요.$' + \
        '4. 키친타올에 수분기 제거하고 볼에 넣어주세요.$' + \
        '5. 토마토는 십자로 썰어 주고 다시 반으로 잘라서 씨를 제거해요.$' + \
        '6. 설탕, 깨소금, 현미식초, 양조간장, 참기름을 섞어 양념을 만드세요$' + \
        '7. 볼에 오이와 토마토, 양념 넣어 주고 살살 버무려 주면 됩니다.$'
recipeTime = '20분'
difficulty = 'easy'
Classification = '채소류'
method = '절임'

# %%
recipeName = '새우볶음밥'
filename = '20.jpg'
process = '1. 당근 1/3개와 양파 1/2개는 다지고 대파는 송송 썰어주세요.$' + \
        '2. 냉동 새우 살은 해동 후 물로 두어 번 헹궈 체에 밭쳐 물기를 빼주세요.$' + \
        '3. 볼에 계란 3개를 깨서 넣고 소금도 약간 넣어 잘 섞어주세요.$' + \
        '4. 중불로 예열한 팬에 식용유 3 큰 술을 넣고 야채부터 달달 볶아주세요. 새우 살도 넣어주시고요.$' + \
        '5. 새우 살이 불그스름해지면 가스불을 꺼줍니다. 밥 두 공기를 넣고 잘 섞어주세요.$' + \
        '6. 중약 불에서 굴 소스 1 큰 술을 넣고 잘 섞어주세요. 간은 소금으로 맞춰주시고요.$' + \
        '7. 가스불을 끄고, 통깨와 후춧가루 적당량, 참기름 1 큰 술을 넣고 마무리해줍니다.$' + \
        '8. 계란 스크램블은 약불로 예열한 팬에 기름을 약간 부어준 다음 계란물을 부어 젓가락으로 휙휙 저어주세요.$' + \
        '9. 약 80% 정도 익었을 때 불을 꺼주세요. 잔열로 나머지를 살짝 더 익혀준 뒤 새우볶음밥에 올려주세요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '해산물'
method = '볶음'

# %%
recipeName = '순대볶음'
filename = '21.jpg'
process = '1. 양파, 당근 채썰고, 양배추는 손가락 마디만큼 잘라줍니다. 순대도 한 입 크기로 잘라주세요.$' + \
        '2. 깻잎도 돌돌돌 말아서 채 썰어줍니다.$' + \
        '3. 고춧가루 2 큰 술, 고추장 1 큰 술, 진간장 2 큰 술, 설탕 0.5 큰 술, 올리고당 1 큰 술, 매실액 1 큰 술, 다진 마늘 1 큰 술, 참기름 1 큰 술, 후춧가루 약간으로 양념을 만듭니다.$' + \
        '4. 식용유 2 큰 술 두른 팬에 손질한 채소를 넣고 볶아줍니다.$' + \
        '5. 당근이 노랏빛이 되면 중약불에서 순대와 떡, 양념장을 넣고 잘 섞어주며 볶아줍니다.$' + \
        '6. 순대볶음 위에 앞에 채 썰어놓은 깻잎 올려주고 통깨 솔솔 뿌려주면 완성입니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '스팸마요덮밥'
filename = '22.jpg'
process = '1. 스팸은 작은크기로 깍뚝 썰기해서 팬에 노릇하게 구워 준비해주세요.$' + \
        '2. 계란은 잘풀어 스크램블을 만들어 준비해줍니다.$' + \
        '3. 간장4,설탕2,물4스푼을 팬에 넣고 약불에서 15초간 졸여 주세요. 너무 오래 끓이면 안되요.$' + \
        '4. 밥한공기에 계란과 스팸을 얹고 소스를 넣은후 마요네즈를 취향껏 뿌려 줍니다. 김가루도 얹어주세요.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '토마토 두부 카프레제'
filename = '23.jpg'
process = '1. 토마도와 두부는 먹기 좋게 얇게 썰어주세요. 한입크기면 더 좋죠.$' + \
        '2. 토마토와 두부를 교차로 접시에 올려 줍니다.$' + \
        '3. 발사믹 식초와 올리브유를 섞어서 올려도 되고 따로 따로 뿌려 주어도 되요.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '무침'

# %%
recipeName = '베이컨치즈 밥말이'
filename = '24.jpg'
process = '1. 밥에 소금과 후추로 밑간을 해줍니다.$' + \
        '2. 참기름과 깨를 약간 넣고 먹기 좋은 크기로 뭉쳐줍니다.$' + \
        '3. 슬라이스 치즈를 반으로 칼집을 내어 주세요.$' + \
        '4. 베이컨을 깔고 그 위로 치즈,밥을 올리고 말아줍니다.$' + \
        '5. 팬에 돌돌 돌려가면서 노릇하게 구워줍니다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '까르보나라 떡볶이'
filename = '25.jpg'
process = '1. 떡볶이떡을 빼서 찬물에 약 20분정도 불려주세요. 대략 2인분이라고 생각하시면 되요.$' + \
        '2. 끓는물에 약 3~5분정도 데쳐서 찬물에 헹궈주세요. 이때에 브로컬리도 끓는물에 데쳐주세요.$' + \
        '3. 팬에 기름을 두른후 다진마늘을 넣고 마늘향이 올라올때까지 볶아주세요.$' + \
        '4. 향이 올라오면 베이컨과 양파를 넣고 볶아주시구요.$' + \
        '5. 이후엔 불려놓은 떡을 넣고 약 2분정도 재료와 함께 볶아주시다가 우유 2컵(=400ml)을 넣고 끓여주세요.$' + \
        '6. 간은 이때에 하시면 되는데요. 허브솔트로 대략 2번정도 톡톡해서 넣으시면 되요.$' + \
        '7. 우유거품이 올라오기 시작하면 치즈와 미리 데쳐놓았던 브로컬리를 넣고 치즈가 녹을때까지 끓여주세요.$' + \
        '8. 우유크림소스가 어느정도 걸죽하니 노오란 색감을 띄면 달걀 노른자를 톡 넣고 휘리릭 섞어서 1~2분정도 끓여주시면 되세요.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '유제품'
method = '끓이기'

# %%
recipeName = '고구마 닭볶음'
filename = '26.jpg'
process = '1. 간장1T, 올리고당2T, 맛술 0.5T, 다진마늘1T, 후추조금 넣고 먹기 좋게 손질해 둔 닭과 섞어 10분정도 재워두세요$' + \
        '2. 고구마는 깨끗이 씻어 껍질째 준비하고 파프리카는 먹기 좋게 정사각형으로 썰어주세요.$' + \
        '3. 브로콜리는 한입크기로 자른 후 1차 흐르는 물 -> 2차 베이킹소다 푼 물 -> 3차 식초물에 씻어주세요.$' + \
        '4. 세척이 끝난 브로콜리는 끓는 물에 30초 정도 삷아서 준비합니다.$' + \
        '5. 팬에 식용유를 두르고 가장 늦게 익는 고구마부터 볶아주세요.$' + \
        '6. 고구마가 노랗게 올라오면 재워둔 닭고기와 파프리카를 넣고 센불에 볶아줍니다. 양념이 잘 배도록 잘 섞어주세요.$' + \
        '7. 닭이 서서히 익어갈 때 브로콜리를 넣어주세요.$' + \
        '8. 센불에 양념이 졸아들 때까지 볶아줍니다. 고구마는 젓가락으로 찔러보고 닭은 살짝 찢어봐서 익었으면 불을 끕니다$'
recipeTime = '60분'
difficulty = 'easy'
Classification = '육류'
method = '볶음'

# %%
recipeName = '오이크래미 샐러드'
filename = '27.jpg'
process = '1. 오이는 3등분한뒤 반으로 잘라줍니다$' + \
        '2. 씨는 물기가 많이 생기고 무를수 있어서 제거해줍니다.$' + \
        '3. 오이는 얇게 채썰어 소금에 잠시 절입니다.$' + \
        '4. 크래미를 꺼내어 얇게 찢어줍니다.$' + \
        '5. 절여진 오이는 손으로 살짝 짜줍니다.$' + \
        '6. 오이와 크래미를 볼에 넣고 마요네즈,다진마늘,설탕,연겨자를 넣어줍니다.$' + \
        '7. 그릇에 옮기고 깨를 뿌리면 완성!$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '해산물'
method = '절임'

# %%
recipeName = '버섯 뜰깨소스 무침'
filename = '28.jpg'
process = '1. 느타리버섯은 적당한 두께로 찢어서 준비하고, 표고버섯은 두툼하게 슬라이스해서 준비해요.$' + \
        '2. 끓는 물에 소금을 약간만 넣어서 느타리버섯을 데쳐내고, 표고버섯도 넣어서 살짝 데쳐내 물기를 빼주세요.$' + \
        '3. 체에 밭쳐 물기를 뺀 다음, 양념하기 전에 손으로 한번 더 물기를 짜주면 좋아요.$' + \
        '4. 멸치액젓 1Ts, 비정제 황설탕 1/2ts, 들기름 2ts을 잘 섞어서 양념을 준비해요.$' + \
        '5. 물기를 뺀 버섯에 양념을 넣어서 고루 섞어줍니다.$' + \
        '6. 액젓과 양념들이 고루 배이면 들깻가루를 넣어서 섞어주고, 송송 썬 쪽파를 넣어서 섞어주고 마무리 해주세요.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '무침'

# %%
recipeName = '가지그라탕'
filename = '29.jpg'
process = '1. 가지는 적당한 크기의 주사위 모양으로 자르고, 마늘은 다져 준다.$' + \
        '2. 양파는 적당한 크기로 다져 준다.$' + \
        '3. 양파를 넣고, 소금, 후추를 넣은 뒤 가지를 넣어준다.$' + \
        '4. 야채가 살짝 숨이 죽을 정도로 볶아준 뒤 토마토소스를 넣는다.$' + \
        '5. 오븐 그릇에 담아준 뒤, 모차렐라 치즈를 뿌려준다.$' + \
        '6. 180도 오븐에 10분간 굽는다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '참치오이롤'
filename = '30.jpg'
process = '1. 참치캔을 따서 기름을 제거하고 그릇에 담은 다음, 숟가락으로 으깨줍니다.$' + \
        '2. 양파 4분의 1조각도 다져서 준비하고요.$' + \
        '3. 으깬 참치에 양파를 넣고 분량의 양념을 넣고 섞어 주세요.$' + \
        '4. 오이는 흐르는 물에 깨끗이 씻은후 필러를 이용해서 포를 떠듯이 한겹 한겹 벗겨내줍니다.$' + \
        '5. 밥1공기도 준비해주고요, 그냥 사용해도 무방하나 참기름, 소금으로 살짝 간해주면 더 맛있게 먹을 수 있어요.$' + \
        '6. 도마위에 오이를 펼쳐놓고 주먹밥을 만들듯 밥을 뭉쳐서 오이 너비에 맞춰 손으로 빚고 올려줍니다.$' + \
        '7. 돌돌 말아주세요.$' + \
        '8. 참치샐러드를 올려주어 참치오이롤초밥을 완성합니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '해산물'
method = '무침'

# %%
recipeName = '오징어쪽파 강회'
filename = '31.jpg'
process = '1. 오징어는 흐르는 물에 깨끗하게 씻은 뒤 끓는 물에 1분 10초간 데쳐주세요. 채반에 밭쳐 열을 한 김 식혀주세요.$' + \
        '2. 냄비에 다시 물을 붓고 끓여주세요. 끓어오르면 소금 1작은술을 넣고 쪽파를 흰부분부터 넣어 30초간 데쳐주세요.$' + \
        '3. 데친 쪽파는 재빨리 찬물에 여러 번 헹군 뒤 물기를 꼭 짜주세요.$' + \
        '4. 오징어 다리는 가닥가닥 썰어주세요. 다리 길이에 맞게 파프리카도 채 썰어 준비해주세요.$' + \
        '5. 몸통은 모양을 그대로 살려 가로로 썰어주세요.$' + \
        '6. 파프리카와 오징어 다리를 가지런히 두고 쪽파를 돌돌 말아주세요.$' + \
        '7. 쪽파를 말아줄 땐 세로로 위치를 잡아준 뒤 가로로 돌돌 말아 묶어주면 됩니다. 끝부분은 돌돌 말아진 부분에 살짝 꽂아주면 끝!$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '데치기'

# %%
recipeName = '감자어묵국'
filename = '32.jpg'
process = '1. 물 7컵에 다시재료를 넣어주고 중약불에서 뭉근하게 끓여 육수를 내줍니다.$' + \
        '2. 감자와 양파는 채썰어주고, 어묵과 대파는 어슷 썰어주세요.$' + \
        '3. 육수가 끓기 시작하면 감자를 먼저 넣어 중약불에서 5분간 끓여 익혀줍니다. 그리고 국간장 1큰술을 더해 기본적인 간을 맞춰주세요.$' + \
        '4. 감자가 반투명하게 익어가면 어묵과 양파, 대파를 넣어 끓여주세요.$' + \
        '5. 다진마늘 0.5큰술과 고춧가루를 살짝 더해줍니다.$' + \
        '6. 모든 재료가 고르게 익고 국물에서 맛이 배어나오기 시작하면 소금과 후추로 간을 조절해주고 마무리해줍니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '해산물'
method = '끓이기'

# %%
recipeName = "단호박 에그슬럿"
filename = '33.jpg'
process = '1. 단호박을 전자렌지에 2분 30초간 돌려준다. 꺼낸 후 단호박의 윗부분을 잘라준다.$' + \
        '2. 수저로 단호박 속을 파내준다.$' + \
        '3. 계란 3알을 넣어주고 노른자를 포크로 터트려준다.$' + \
        '4. 소금 1/2수저, 설탕 1/2수저를 넣어준다.$' + \
        '5. 치즈 3장을 잘게 찢어 넣어준다. 피자 치즈 4수저를 올려준다.$' + \
        '6. 전자렌지에 9분간 돌려준다.$'
recipeTime = '20분'
difficulty = 'easy'
Classification = '채소류'
method = '찜'

# %%
recipeName = '오이볶음'
filename = '34.jpg'
process = '1. 오이 3개를 깨끗이 씻어서 동그랗게 얇게 슬라이드 해주세요.$' + \
        '2. 잘라놓은 오이에 소금1큰술을 넣고 10분간 절여주세요.$' + \
        '3. 절여진 오이는 씻지마시고 그대로 물기를 꼭 짜주세요.$' + \
        '4. 팬에 올리브유 2큰술을 넣고 물기를 짠 오이를 넣어주시고 1분간 볶아주세요.$' + \
        '5. 들깨가루를 2큰술을 넣고 들깨가루가 뭉치지않게 잘 섞어주세요.$' + \
        '6. 들깨가루를 넣고 1분간만 더볶아주시고 불을 꺼주세요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '옥수수참치전'
filename = '35.jpg'
process = '1. 참치와 옥수수의 물기를 빼주세요.$' + \
        '2. 피망과 양파는 잘게 다져 준비해주세요.$' + \
        '3. 준비해놓은 재료를 볼에 넣고, 부침가루나 밀가루 2스푼, 계란 2개를 넣어 잘 섞어주세요.$' + \
        '4. 섞어준 재료를 기름을 두룬 팬에 알맞은 크기로 올리고, 약불에서 천천히 구워주세요.$' + \
        '5. 노릇노릇할 정도로 굽고, 키친타올에 올려서 기름기를 좀 빼주세요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '해산물'
method = '부침'

# %%
recipeName = '연어간장조림'
filename = '36.jpg'
process = '1. 연어를 먹기좋은 사이즈로 등분합니다.$' + \
        '2. 연어에 소금, 후추, 정종 1/2스푼으로 밑간을 합니다.$' + \
        '3. 양념장을 만들어요. 간장 1.5스푼, 올리고당 1스푼, 물 반컵, 참기름, 다진마늘, 다진양파를 섞어요.$' + \
        '4. 카놀라유를 두른 팬에 마늘을 편썰어 향을내 볶아줍니다.$' + \
        '5. 밑간이 된 연어를 중불에서 구워줍니다.$' + \
        '6. 한면이 익었을때 뒤집어 양념장의 반을 넣고 채썬 양파1/4 도 함께 넣어요. 양념장이 끓고 1분후 뒤집어서 나머지 양념장을 넣어요.$' + \
        '7. 그릇에 담고 얇게 채썬 양파와 쪽파로 고명을 올리면 완성입니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '해산물'
method = '조림'

# %%
recipeName = '가지말이'
filename = '37.jpg'
process = '1. 가지는 약0.5cm 두께로 슬라이스 해주세요. 채칼을 사용해도 되고요.$' + \
        '2. 파프리카는 길게 채썰어주세요.$' + \
        '3. 닭가슴살은 훈제닭가슴살을 이용하거나 익혀서 잘라주세요.$' + \
        '4. 후라이팬에 기름을 두르지 않고 슬라이스한 가지를 구워주세요.$' + \
        '5. 구운 가지 위에 파프리카, 훈제닭가슴살, 새싹샐러드를 올려 돌돌 알아주면되요.$' + \
        '6. 샐러드 소스 분량대로 만들어 찍어먹어도 되고 간편하게 가지말이샐러드 위에 뿌려 나가도 된답니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '두부짜글이'
filename = '38.jpg'
process = '1. 먼저 양파1/2개와 청양고추2개를 먹기좋게 썰어주세요.$' + \
        '2. 고춧가루1.5T, 고추장1.5T, 간장2T, 설탕1T, 다진마늘1/2T를 섞어서 양념장을 만들어주세요.$' + \
        '3. 낮은 후라이팬에 양파를 올리고 두부를 삥 둘러서 올려주세요.$' + \
        '4. 물은 두부가 자작하게 잠길정도만 넣어주시고 양념장을 그 위에 올려주세요.$' + \
        '5. 뚜껑을 닫고 약한불에 졸여주세요.$' + \
        '6. 뚜껑을 잠시 열고 대파와 청양고추2개를 넣어서 다시 국물이 없어질정도로 졸여주세요.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '끓이기'

# %%
recipeName = '굴회'
filename = '39.jpg'
process = '1. 생굴을 준비합니다. 깨끗이 씻어서 가지런히 접시에 놓고요.$' + \
        '2. 레몬즙을 뿌려 줍니다. 그리고 올리브유도 같이 뿌려줍니다.$' + \
        '3. 쪽파를 송송 썰어서 위에 뿌려주시고요.$' + \
        '4. 통깨 솔솔 뿌려주면 완성입니다.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '해산물'
method = '회'

# %%
recipeName = '골뱅이물회'
filename = '40.jpg'
process = '1. 골배이는 물기를빼주세요. 여기에 참기름과 깨소금, 다진마늘을 넣고 버무려주세요.$' + \
        '2. 오이를 채썰고, 양파도 채썰어 물에 담가 매운맛을 제거해주세요.$' + \
        '3. 파프리카, 깻잎 등 그외 야채들도 채썰어주세요.$' + \
        '4. 냉면 육수3개를 냄비에 준비합니다.$' + \
        '5. 양념 재료를 육수에 휘휘 섞어줍니다.$' + \
        '6. 끓는물에 소금넣고 소면도 익혀 준비해주세요.$' + \
        '7. 육수에 야채와 골뱅이를 넣어 섞어줍니다.$' + \
        '8. 소면얹어서 깨소금 뿌리고 얼음동동 띄워내면 완성!$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '회'

# %%
recipeName = '고등어무조림'
filename = '41.jpg'
process = '1. 무와 대파는 흐르는 물에 씻은 후 무는 도톰하게 반달 썰어 주고 대파는 어슷 썰어 줍니다.$' + \
        '2. 고등어는 흐르는 물에 깨끗하게 씻어 줍니다.$' + \
        '3. 분량의 양념장 재료 진간장, 고추장, 고춧가루, 매실액, 맛술, 올리고당, 다진 마늘, 후춧가루를 넣어 고루 섞어서 양념장을 만들어 줍니다.$' + \
        '4. 냄비 바닥에 무를 깔고 씻어 놓은 고등어를 올린 후 대파를 얹어 주고 양념장을 끼얹어 준 다음 물을 부어 줍니다.$' + \
        '5. 가스 불에 올려 센 불에서 끓여 주다가 한소끔 끓으면 불을 줄이고 간이 고루 배도록 중간 중간 양념장을 끼얹어 주면서 조려 줍니다.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '조림'

# %%
recipeName = '가지덮밥'
filename = '42.jpg'
process = '1. 가지는 작은 크기로 깍뚝썰기를 해요.$' + \
        '2. 양파, 홍고추, 대파는 송송 썰어줍니다.$' + \
        '3. 달군 팬에 기름 조금 두르고 가지 양파, 대파 넣어 볶아주고 양파가 투명하게 볶아지면 물 4,굴 소스 반, 설탕 약간, 간장 1 넣고 볶아주세요.$' + \
        '4. 재료에 간이 배이면 고추 넣고 한 번 볶아주고 불 끄고 들기름 1t 과 후춧가루 넣어주세요.$' + \
        '5. 달걀 프라이나 스크램블 만들어 밥위에 볶은가지와 달걀 올려 마무리합니다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '볶음'

# %%
recipeName = '오삼불고기'
filename = '43.jpg'
process = '1. 삽겹살,오징어를 적당한 크기로 잘라 준비해 줍니다.$' + \
        '2. 양념장을 분량대로 만들어 줍니다. 설탕2,고춧가루3.간장1.5,다진마늘1.5,고추장2.매실액0.5,후추 적당히 섞어줍니다.$' + \
        '3. 중간 불로 달군 팬에 식용유를 둘러 대파를 볶습니다.$' + \
        '4. 파 향이 올라오면 삽겹살을 볶습니다.$' + \
        '5. 삽겹살의 겉면이 익으면 센 불로 올려 오징어와 양념장을 넣고 30초간 볶습니다.$' + \
        '6. 양파를 넣고 볶고 참기름 깻잎을 얹어 마무리합니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '돼지고기 생강구이'
filename = '44.jpg'
process = '1. 강판에 생강을 갈아 둡니다.$' + \
        '2. 생고기에 적당히 소금 간을 먼저 해둡니다.$' + \
        '3. 후라이팬에 기름을 두루지 않고 중불로 굽다가, 고기의 안까지 열이 전해졌다 싶으면 강불로 올려주세요.$' + \
        '4. 고기를 뒤집어서 노르스름하게 익힌 다음에 준비해둔 갈아놓은 생강을 넣고 돼지기름에 조금 볶다가 청주와 미림을 넣습니다. $' + \
        '5. 쌘불로 알콜의 향을 다 날린 후 설탕을 넣습니다.$' + \
        '6. 몇번 섞어 준 뒤, 수분이 어느 정도 날아간 다음에 간장을 넣어 마무리 해주면 됩니다.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '육류'
method = '굽기'

# %%
recipeName = '고구마크로켓'
filename = '45.jpg'
process = '1. 고구마는 흐르는 물에 씻은 후 반으로 썰어서 삶은 후 고구마 껍질을 제거하고 뜨거울 때 포크를 이용해 으깨어줍니다.$' + \
        '2. 양파와 당근은 껍질을 제거하고 흐르는 물에 씻은 후 잘게 다져준다.$' + \
        '3. 햄은 끓는 물에 살짝 데쳐서 다져주고 슬라이스치즈도 잘게 다져줍니다.$' + \
        '4. 으깬 고구마에 양파, 당근, 햄, 슬라이스치즈, 소금, 후춧가루를 넣어 고루 섞어서동글동글한 모양으로 만들어 줍니다.$' + \
        '5. 밀가루, 빵가루, 달걀물 순으로 튀김 옷을 입혀줍니다.$' + \
        '6. 달군 프라이팬에 식용유를 붓고 170도씨 온도에서 노릇노릇하게 튀겨서 키친타월을 이용해 기름기를 제거해줍니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '튀김'

# %%
recipeName = '고등어강정'
filename = '46.jpg'
process = '1. 고등어는 씻어서 뼈를 발라 냅니다.$' + \
        '2. 고등어는 먹기 좋은 크기로 잘라 후추와 생강술을 뿌려 둡니다.$' + \
        '3. 자른 고등어는 전분을 2번 묻혀 주세요.$' + \
        '4. 팬에 기름을 넉넉히 두르고 열이 오르면 전분 묻힌 고등어를 노릇하게 튀겨 주세요.$' + \
        '5. 간장,물,맛술,물엿,고추,후추 넣어 소스 끓입니다.$' + \
        '6. 소스가 바글바글 끓으면 튀긴 고등어 넣어 소스가 남지 않을때 까지 졸입니다.$'
recipeTime = '30분'
difficulty = 'hard'
Classification = '해산물'
method = '튀김'

# %%
recipeName = '중국식 닭가슴살튀김'
filename = '47.jpg'
process = '1. 닭가슴살은 소금,후추,청주에 30분 밑간합니다. 고기를 재우는 동안 채소를 손질해요.$' + \
        '2. 양념(소스)을 미리 타주세요.$' + \
        '3. 밑간한 닭가슴살을 키친타올로 잘 닦아줍니다. 밀가루-달걀물-빵가루를 통에 담아주세요.$' + \
        '4. 고기에 밀가루를 묻혀주세요. 다시 달걀물을 묻히세요.$' + \
        '5. 마지막으로 빵가루를 묻혀요. 손으로 꾸욱꾹 눌러서 묻히면 튀김옷이 잘 벗겨지지 않아요.$' + \
        '6. 포도씨유 넣은 팬을 약불에서 가열해주세요. 고기를 넣고 뚜껑을 덮어주세요. 5분 후 뚜껑을 열고 뒤집어주세요. 다시 5분을 뚜껑 덮고 튀겨주세요.$' + \
        '7. 튀긴 고기는 기름이 빠질 수 있는 망에 올려요.$' + \
        '8. 고기를 튀기는 동안, 양상추는 먹기좋은 크기로 찢어 놓고 대파는 채썰어 큰접시에 펼쳐서 담아요. 고기도 썰어주세요.$' + \
        '9. 준비해둔 소스를 숟가락으로 올려주세요. 무순도 이쁘게 올려요. 완성입니다.'
recipeTime = '60분'
difficulty = 'hard'
Classification = '육류'
method = '튀김'

# %%
recipeName = '메추리알 햄조림'
filename = '48.jpg'
process = '1. 햄 1/2캔 사각으로 잘라주세요.$' + \
        '2. 간장 6스푼, 물은 종이컵1잔 분량, 설탕 1스푼 반을 넣어주세요.$' + \
        '3. 다진마늘 1커피스푼과 매콤한 맛을 좋아한다면 청양고추 또는 꽈리고추 추가합니다.$' + \
        '4. 7분~8분 동안 졸여주세요.$' + \
        '5. 가스불 끄기 직전 올리고당 한바퀴 빙 둘러주시고 참기름 1스푼, 통깨 뿌리면 완성!$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '육류'
method = '조림'

# %%
recipeName = '소고기 감자조림'
filename = '49.jpg'
process = '1. 고기는 불고기용으로 먹기 좋은 크기로 썰어서 다진마늘 반큰술, 청주 2큰술, 후추 약간을 넣고 재워 둡니다.$' + \
        '2. 감자는 1cm내의 두께로 먹기 좋게 썰어서 찬물에 약 20~30분 정도 담궈 전분기를 제거해 줍니다.$' + \
        '3. 팬에 기름을 두르고 감자를 볶아주다가 겉이 노릇하게 코팅이 되면 다른 그릇에 옮기세요.$' + \
        '4. 불고기 재워둔 것을 넣고 살짝이 핏물이 안보이게만 볶아주세요.$' + \
        '5. 움푹한 팬에 볶은 감자와 고기를 넣고 물 1머그컵과 간장 3큰술을 넣어 센불에서 조리다가 끓으면 중불에서 조려줍니다.$' + \
        '6. 국물이 2/3정도 조려지면 올리고당 2큰술을 넣고 더 졸여주세요.$' + \
        '7. 감자가 익어 다 조려지면 청홍고추를 어슷 썰어서 놓았다가 넣고, 참기름 1큰술과 통깨를 넣어 살살 버무려 줍니다.$' 
recipeTime = '30분'
difficulty = 'normal'
Classification = '육류'
method = '조림'

# %%
recipeName = '쫄면'
filename = '50.jpg'
process = '1. 고춧가루 6큰술, 고추장 4큰술, 식초 9큰술, 간장 2큰술, 설탕 6큰술, 간마늘 3큰술, 물 6큰술을 넣고 고루 섞어준다.$' + \
        '2. 팔팔 끓는 물에 소금 약간 넣고 뚜껑을 연채로 1~2분 삶아 찬물에 헹궈 물기를 뺀다.$' + \
        '3. 당근, 적채, 오이는 채 썬다.$' + \
        '4. 상추는 깨끗이 씻어 손으로 먹기 좋은 크기로 자른다.$' + \
        '5. 팔팔 끓는 물에 식초 3큰술을 넣고 3분 30초 정도 삶아 찬물에 씻어준다.$' + \
        '6. 삶은 면과 채 썬 당근, 오이, 적채, 상추, 콩나물을 넣고 양념장과 계란을 올려 주면 쫄면 만드는법 완성입니다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '비빔'

# %%
recipeName = '비빔만두'
filename = '51.jpg'
process = '1. 오이와 당근,사과등이 있으면 추가로 채썰기.$' + \
        '2. 양파는 얇게 채썰고 매운기제거를 위해 찬물에 10분가량 담궈준뒤, 물기를 제거해주세요.$' + \
        '3. 양배추와 상추10장은 얇게 채썰어주세요.$' + \
        '4. 소금약간넣은 물에 소면도 삶아준뒤 찬물에 헹궈주세요$' + \
        '5. 만두는 노릇하게 앞,뒤로 구워주세요.$' + \
        '6. 야채와 국수는 버무려 만두와 함께 내주시면 완성!$' 
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '비빔'

# %%
recipeName ='날치알밥'
filename = '52.jpg'
process = '1. 단무지, 맛살을 잘게 다져주세요.$' + \
        '2. 김치는 잘게잘게 썰어 간장 0.5, 설탕1, 참기름1, 통깨를 섞어주세요.$' + \
        '3. 뚝배기 안에 참기름 1큰술, 밥을 담아주세요.$' + \
        '4. 양념한 김치, 단무지, 맛살, 채소 올리고 날치알 듬뿍!$' + \
        '5. 3~4분간 약불로 두고 타다닥 맛있는 소리가 나면 불을 꺼주세요.$' + \
        '6. 김가루 솔솔, 통깨 팍팍! 완성!$'
recipeTime = '20분'
difficulty = 'normal'
Classification = '채소류'
method = '비빔'

# %%
recipeName = '비빔당면'
filename = '53.jpg'
process = '1. 고춧가루2T, 설탕1T, 깨1T, 간장4T, 식초1.5T, 올리고당2T, 다진마늘 0.5T, 참기름2T, 다진파2T 를 넣고 양념장으로 만들어요.$' + \
        '2. 깻잎과 당근은 깨끗이 씻어서 깻잎은 반으로 접어서 길고 얇게 채썰고, 당근도 얇게 채썰어주세요.$' + \
        '3. 계란1개는 잘 풀어주세요.$' + \
        '4. 후라이팬에 기름을 두르고 계란물을 부어서 계란지단을 만들어줍니다.$' + \
        '5. 다 익은 계란지단은 길게 채썰어주세요.$' + \
        '6. 당면을 7~8분정도 삶아줍니다.$' + \
        '7. 다 삶아진 당면은 찬물로 헹궈주세요.$' + \
        '8. 그릇에 당면을 담고, 당근,계란,깻잎 고명을 얹어줍니다. 그리고 취향에 맞고 소스를 얹어줍니다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '비빔'

# %%
recipeName = '상추겉절이'
filename = '54.jpg'
process = '1. 먼저 깨끗이 씻은 상추는 먹기좋은 크기로 썰어 줍니다.$' + \
        '2. 상추만 넣으면 심심하니까 아삭아삭 양파도 얇게 채 썰어 넣어주었어요.$' + \
        '3. 참기름과 깨를 제외한 양념을 다 섞어주세요.$' + \
        '4. 상추에 양념장을 넣어주시되 처음부터 다 넣지 마시고 간을 보시면서 본인 기호에 맞게 추가하세요.$'+ \
        '5. 고소한 참기름 1스푼, 깨 1스푼도 넣고 가볍게 조물조물 무치면 완성!$' 
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '비빔'

# %%
recipeName = '오징어초무침'
filename = '55.jpg'
process = '1. 오이는 반달로 썰어서 소금을 약간 넣고 15분간 절여주세요.$' + \
        '2. 오징어는 안쪽에 칼집을 내서 썰어주세요.$' + \
        '3. 끓는 물에 오징어를 넣고 데쳐주세요.$' + \
        '4. 양파와 당근은 얇게 채썰어주세요.$' + \
        '5. 양념장을 만들어 주세요.$' + \
        '6. 오이는 찬물에 헹군후 물기를 꼭짜준 후 모든 재료를 넣고 함께 버무려주세요.$' + \
        '7. 접시에 담아 통깨 솔솔 뿌려주면 새콤달콤 매콤한 오징어초무침 완성이예요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '해산물'
method = '비빔'

# %%
recipeName = '달걀찜'
filename = '56.jpg'
process = '1. $' + \
        '2. 그릇에 달걀 6개를 풀어주시고, 다진파 3T, 참기름 두방울, 소금 1/2~2/3T정도를 넣고 잘 섞어줍니다.$' + \
        '3. 뚝배기에 멸치다시마육수(없으면 물) 1컵 반을 넣고 센불에서 끓여주세요.$' + \
        '4. 달걀풀어 놓은물을 넣고, 중불로 줄여줍니다. 1~2분정도 달걀을 익혀 주세요.$' + \
        '5. 나무주걱이나 수저로 바닥면까지 저어주면서 4~5분정도 경과되면 완성입니다.$' 
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '찜'

# %%
recipeName = '오이소박이'
filename = '57.jpg'
process = '1. 굵은 소금으로 깨끗이 씻은 오이는 한개당 4등분으로 잘라 주세요. 오이 아래쪽에 약 1cm정도 여유를 두고 십자 모양으로 잘라줍니다.$' + \
        '2. 물 800ml에 굵은 소금4스푼을 넣고 센불에서 팔팔 끓여 줍니다.$' + \
        '3. 오이에 팔팔 끓은 소금물을 부어 약 30분 정도 절여 주세요. 한 두번 뒤적여 주세요.$' + \
        '4. 오이가 절여지는 동안 부추,양파,당근을 썰어주세요.$' + \
        '5. 멸치액젓2스푼,새우젓1/3스푼,고추가루4스푼,다진마늘1스푼,설탕1스푼을 섞어 양념장을 만들어 주세요.$' + \
        '6. 양념장에 손질한 부추,양파,당근을 넣고 가볍게 버무려 줍니다.$' + \
        '7. 절여진 오이는 체에 받쳐 물기를 제거해 준 뒤 방금 만든 양념장을 오이속으로 적당히 넣어주시면 끝입니다.$'
recipeTime = '60분'
difficulty = 'normal'
Classification = '채소류'
method = '절임'

# %%
recipeName = '매쉬드포테토'
filename = '58.jpg'
process = '1. 껍질을 벗긴 감자는 익히기 쉽도록 작게 썰어주세요.$' + \
        '2. 감자는 15분 정도 푹 쪄주세요. 젓가락으로 찔렀을 때 끝가지 푹 들어가면 꺼내주세요.$' + \
        '3. 감자는 뜨거울 때 포크로 으깨주시고 소금, 후추로 간을 합니다.$' + \
        '4. 상온에 녹여 둔 버터를 넣어 잘 섞어줍니다.$' + \
        '5. 따뜻한 우유를 부어가며 주걱으로 잘 섞어주세요.$' + \
        '6. 농도는 본인 취향에 맞춰 조절 후 파슬리를 뿌리면 완성입니다.$' 
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '찜'

# %%
recipeName ='찜닭'
filename = '59.jpg'
process = '1. 큰 볼에 당면 한줌 분량을 넣고 당면이 잠길 정도의 찬물을 넣어주세요. 1시간 정도 불려주세요.$' + \
        '2. 당근 1/3개는 둥글 납작한 모양으로, 양파 1개는 듦성 큼직하게 썰어주세요$' + \
        '3. 오이 1/3개는 어슷썰기로, 대파 1/2개는 손가락 길이 정도로 큼직하게 썰어주세요.$' + \
        '4. 알이 굵은 감자 2개는 둥글 납작하게 썰어서 찬물에 10분 담가서 전분을 제거해주세요.$' + \
        '5. 손질되고 토막 난 닭 1마리는 흐르는 물로 1차 세척을 해주세요.$' + \
        '6. 큰 볼에 닭이 모두 잠길 정도의 우유를 담고 약 30분 동안 잡내를 제거해주세요.$' + \
        '7. 닭은 흐르는 찬물로 한번 헹궈 주세요. 냄비에 닭을 모두 넣고 물과 미림 3스푼 혹은 소주 3스푼을 넣고 강불로 끓여주세요.$' + \
        '8. 보글보글 끓기 시작하면 닭은 바로 건져내 주시면 된답니다.$' + \
        '9. 냄비에 물을 모두 버리고 종이컵 4컵 분량의 물과 닭을 넣어주세요.$' + \
        '10. 진간장 13스푼을 넣어주시고 커피 1스푼을 넣고 10분 정도 강불에서 끓여주세요.$' + \
        '11. 10분 후 설탕 3스푼과, 물엿 6스푼을 넣고 살살 저어 주시며 1분 동안 끓여주세요.$' + \
        '12. 깔끔한 국물맛을 위해 올라오는 거품은 걷어내 주세요.$' + \
        '13. 고추와 대파를 제외하고 손질해 놓은 감자, 당근, 오이, 양파를 넣고 으깨지지 않게 살살 저어 주세요.$' + \
        '14. 다진 마늘 3스푼, 후추 톡 3번 넣고 뚜껑을 닫고 10분간 강불로 끓여주세요.$' + \
        '15. 손질해 놓은 대파 1/2개, 홍고추 1개 불려놓은 당면 한 줌을 모두 넣어주세요.$' + \
        '16. 정확히 2분 30초만 끓여주시는 게 최적의 당면 식감을 만드는 포인트!$'
recipeTime = '60분'
difficulty = 'hard'
Classification = '육류'
method = '찜'

# %%
recipeName = '양파장아찌'
filename = '60.jpg'
process = '1. 양파 6개, 청량고추 6개를 썰어주세요.$' + \
        '2. 양파장아찌의 양념을 준비해줍니다. 물 : 간장 : 식초 : 설탕 - 2: 1: 1: 1 로 하는게 가장 좋은 비율입니다.$' + \
        '3. 용기에 양파를 담아주고 부어주면 되는데요. 용기는 유리용기를 꼭 써야하며 오래두고 먹을꺼라면 용기소독 해주세요.$' + \
        '4. 유리그릇에 고추 먼저 담고 그 위에 양파 그 위에 다시 고추 이런식으로 켜켜이 담아주세요. $' + \
        '5. 팔팔 끓은 간장물을 바로 부어주세요. 다 부어주신다음 국자로 위에 꾹 눌러주세요.$' + \
        '6. 1시간내지 2시간정도 그대로 놔두었다가 한김 식으면 뒤로 뒤집어서 놓아주세요.$' + \
        '7. 반나절 상온에서 보관한뒤 냉장고로 옮겨서 하루 후에 드시면 되요.$'
recipeTime = '60분'
difficulty = 'easy'
Classification = '채소류'
method = '절임'

# %%
recipeName = '오이장아찌'
filename = '61.jpg'
process = '1. 오이를 3등분으로 썬 후 먹기 좋게 4등분으로 잘라주세요.$' + \
        '2. 썰은 오이는 통에 잘 담아주세요.$' + \
        '3. 냄비에 간장, 식초, 물, 설탕을 100ml씩 넣고 설탕을 녹인 후 불을 켜주세요.$' + \
        '4. 간장물이 끓으면 불을 끄고 뜨거운 김만 식혀주세요.$' + \
        '5. 한김 식힌 뜨거운 간장물을 통에 부은 후 식은 상태에서 냉장고에 하루 보관해주세요.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '채소류'
method = '절임'

# %%
recipeName = '무초절임'
filename = '62.jpg'
process = '1. 무는 씻은 후 껍질을 벗기고 준비합니다.$' + \
        '2. 채를 썰기 위해서는 동글썰기를 하는데요. 먼저 무의 아래 부분을 살짝 잘라내고 도마에 놓고 썰면 고정이 되어 한결 쉽습니다.$' + \
        '3. 채썰기를 해줍니다. 채칼에서보다는 굵게, 무생채할때의 굵기가 적당합니다.$' + \
        '4. 식초 1컵반, 설탕 1컵, 소금 1큰술을 무에 넣고 뒤적입니다. 가끔씩 뒤적여 주세요.$' + \
        '5. 내일 부터 드시면 아주 좋습니다.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '절임'

# %%
recipeName = '칠리새우'
filename = '63.jpg'
process = '1. 야채들을 먹기 좋게 썰어주세요.$' + \
        '2. 새우(소금,후추)를 손질해서 준비해주세요.$' + \
        '3. 튀김가루100g에 물50ml를 섞어 튀김반죽을 만들어주세요.$' + \
        '4. 양념도 미리 만들어주세요. 칠리소스 4, 올리고당 2, 고추장 1, 케찹 3, 청주 1, 식초 1, 굴소스 1스푼씩 섞어주세요.$' + \
        '5. 새우는 튀김가루, 튀김반죽 순으로 뭍혀준 후 달궈진 기름에 넣고 튀겨주세요.$' + \
        '6. 새우를 튀겼으면 이제 야채를 볶아주세요.$' + \
        '7. 야채가 다 익을 때쯤 만들어둔 양념장을 넣고 볶아주세요.$' + \
        '8. 그 위에 튀겨준 새우 넣고 볶으면 완성!$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '튀김'

# %%
recipeName = '양배추쌈'
filename = '64.jpg'
process = '1. 양배추는 심지를 제거하고 하나씩 뜯어 물에 씻어 건진다.$' + \
        '2. 전자레인지 그릇에 양배추와 물을 넣는다.$' + \
        '3. 랩을 씌우고 포크로 구멍을 낸 후 전자레인지에 7~8분 돌린다.$' + \
        '4. 양념을 섞어 쌈장을 같이 만들어 완성한다.$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '삶기'

# %%
recipeName = '동파육'
filename = '65.jpg'
process = '1. 삽겹살 통째로 600그람을 물이 끓을 때 넣어줍니다. 붉은 양파 한개도 껍질채 썰어 넣어요.$' + \
        '2. 중불에서 30분정도 끓여 젓가락이 쑤욱 들어갈 정도로 익으면 삽겹살을 건져주세요. 흐르는 찬물에서 깨끗하게 씻어요.$' + \
        '3. 1.5cm~2cm 두께로 썰어 팬에서 노릇노릇 익힙니다.$' + \
        '4. 물1컵. 간장 3큰 술. 설탕 1큰 술을 넣고 뭉근하게 서서히 조립니다.$' + \
        '5. 국물이 거의 없어지면 꿀 2큰 술 참기름 1작은 술을 넣고 뒤적뒤적 하면서 조금 더 조립니다.$' + \
        '6. 참기름과 소금으로 밑간한 파채를 중심에 올리고 완성된 동파육을 가장자리에 돌려 담기 해요.$'
recipeTime = '90분'
difficulty = 'hard'
Classification = '육류'
method = '삶기'

# %%
recipeName = '스터프드 에그'
filename = '66.jpg'
process = '1. 달걀을 약한불에서 젓가락으로 굴려가며 약 20분정도 삶아주어요.$' + \
        '2. 삶아진 달걀은 찬물에 담가 껍질을 벗겨줍니다.$' + \
        '3. 각각 흰자 양쪽 밑둥을 살짝 잘라내어 평평하게 만들어 흰자가 잘 세워지도록 만듭니다.$' + \
        '4. 반으로 자르고 가운데 노른자 속을 뺍니다.$' + \
        '5. 슬라이스햄은 잘게 썰고 오이는 돌려깍기 하여 잘게 다져 준비해주세요.$' + \
        '6. 노른자에 햄 오이를 넣고 마요네즈 2, 머스터드 0.3, 소금, 후춧가루 약간 으로 간해 섞습니다.$' + \
        '7. 별깍지 끼운 짤주머니에 담아 흰자 위 빙그르르 짜준 뒤 파슬리 잎으로 장식하여 마무리!$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '채소류'
method = '삶기'

# %%
recipeName = '오겹살수육'
filename = '67.jpg'
process = '1. 된장 5T, 소주 5T, 다진 마늘 1T를 넣고 잘 섞어주세요.$' + \
        '2. 잘 섞은 된장을 고기에 잘 골고루 발라 주세요. 그리고 30분 정도 재워주세요.$' + \
        '3. 양파는 채 썰어주고, 대파는 길게 잘라주고, 낮은 냄비에 썰어놓은 양파와 대파를 2/3 정도 깔아주세요.$' + \
        '4. 된장을 바른 오겹살을 채소 위에 넣어주세요.$' + \
        '5. 남은 1/3의 양파와 대파를 고기 위에 올려주고, 통후추를 넣어주세요. 통마늘, 월계수잎 등을 추가로 넣어주셔도 된답니다.$' + \
        '6. 뚜껑을 덮고 약불에서 1시간 삶아줍니다. 불은 센 불 안된답니다.$' + \
        '7. 겉에 붙은 채소들을 잘 털어내고 살짝 식혀준 후 먹기 좋은 크기로 잘라 주시면 돼요.$'
recipeTime = '90분'
difficulty = 'normal'
Classification = '육류'
method = '삶기'

# %%
recipeName = '계란초'
filename = '68.jpg'
process = '1. 계란 15분 정도 삶아 줍니다. 껍질을 벗겨주세요.$' + \
        '2. 계란을 삶을 동안 당근 오이 얇게 채썰어 준비합니다.$' + \
        '3. 삶은 계란은 반을 잘라 주시고 준비한 오이 당근 조금식 올려주세요.$' + \
        '4. 초고추장 조금 올려주시고 통깨 뿌려주면 끝!$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '삶기'

# %%
recipeName = '우유달걀카레'
filename = '69.jpg'
process = '1. 먼저 양파 1/2개 먹기좋은 크기로 잘라주세요.$' + \
        '2. 햄도 한입 크기로 깍뚝 썰어주세요.$' + \
        '3. 뜨겁게 달궈진 냄비에 식용유를 붓고 양파와 햄을 볶아주세요.$' + \
        '4. 양파와 햄이 노릇노릇하게 볶아졌으면 우유 200ml 부어요.$' + \
        '5. 우유가 몽글몽글 끓어오르면 카레가루를 넣어주세요.$' + \
        '6. 카레가 걸쭉해져서 끓어오르면 계란 1개를 넣고 풀어주세요. 다 익으면 안성!$' 
recipeTime = '15분'
difficulty = 'easy'
Classification = '육류'
method = '끓이기'

# %%
recipeName ='호박죽'
filename = '70.jpg'
process = '1. 단호박은 껍질채 흐르는물에 세척해주고 물기가 묻은상태에서 전자렌지에 3분, 뒤집어서 또 3분 돌려주세요.$' + \
        '2. 단호박은 4등분한후 숟가락을 이용하여 씨를 모두 제거해주세요.$' + \
        '3. 그리고 껍질을 벗겨냅니다.$' + \
        '4. 껍질 벗긴 단호박을 듬성듬성 잘라주고 믹서에 넣어주신 후 단호박이 잠길만큼의 물을 넣어 곱게 갈아주세요.$' + \
        '5. 갈아낸 단호박을 냄비에 넣어두세요.$' + \
        '6. 밥을 믹서에 넣어 밥이 잠길만큼의 물을 넣어준후 원하는 입자로 갈아주세요.$' + \
        '7. 냄비에 갈아준 밥도 넣어주고 센불로 저어주며 끓여주세요.$' + \
        '8. 보글보글 끓기시작하면 우유를 넣어줘요.$' + \
        '9. 중불로 줄여 냄비바닥에 누르지 않게 수시로 저어주며 원하는 농도가 될때까지 끓여주세요.$' + \
        '10. 중불을 유지하며 끓여준 호박죽이 원하는 농도가 되었다면 꿀을 넣어 단맛을 추가해주시고 약불로 줄여 5분정도 더 끓여주면 끝.$'
recipeTime = '60분'
difficulty = 'normal'
Classification = '곡류'
method = '끓이기'

# %%
recipeName = '우유드레싱 샐러드'
filename = '71.jpg'
process = '1. 브로콜리는 먹기좋은 크기로 떼어내 씻어준후 끓는물에 소금을 조금 넣고 살짝 데쳐내 물기를 빼줍니다.$' + \
        '2. 칵테일 새우는 깨끗이씻어, 끓는물에 삶아준비합니다.$' + \
        '3. 드레싱재료를 모두 섞어 냉장고에 시원하게 보관해둡니다.$' + \
        '4. 데쳐논 브로콜리와칵테일 새우를 접시에 답고, 만들어놓은 드레싱을 솔솔 뿌려줍니다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '해산물'
method = '데치기'

# %%
recipeName = '팥양갱'
filename = '72.jpg'
process = '1. 냄비에 생수 200mL와 분말한천 4g을 넣고 잘 녹여준다.$' + \
        '2. 설탕 50g을 넣고 녹여준다.$' + \
        '3. 적앙금을 넣어 덩어리 없이 저어준 다음 졸인다.$' + \
        '4. 감시럽을 넣어 윤기가 살짝 나도록 졸인다.$' + \
        '5. 주걱으로 바닥을 긁었을 때 길이 보이면 완성농도.$' + \
        '6. 틀에 넣어 굳혀준다.$' + \
        '7. 냉장고에서 한시간 정도 굳힌 후 먹기 좋은 크기로 잘라준다.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '곡류'
method = '끓이기'

# %%
recipeName = '들깨수제비'
filename = '73.jpg'
process = '1. 밀가루에 계란을 넣어주세요.$' + \
        '2. 물 소주잔 1컵을 반죽의 되기에 맞춰 조금씩 넣어가면서 반죽을 해주세요.$' + \
        '3. 수제비 반죽을 비닐에 덮어 냉장고에 넣어주세요.$' + \
        '4. 부추와 당근을 원하는 모양과 크기로 썰어서 준비해 주세요.$' + \
        '5. 냄비에 밥공기로 물 1컵 반을 넣고 소금과 후추 다진마늘을 넣어 팔팔 끓여주세요.$' + \
        '6. 물이 끓으면 냉장고에 넣어두었던 수제비반죽을 손으로 떼어내어 넣어주세요.$' + \
        '7. 수제비 반죽이 물위로 떠오르면 들깨가루를 넣어주세요. 거품을 제거해주세요.$' + \
        '8. 부추와 당근을 넣고 3분정도 더 끓여주면 완성!$' 
recipeTime = '30분'
difficulty = 'normal'
Classification = '곡류'
method = '끓이기'

# %%
recipeName = '약밥'
filename = '74.jpg'
process = '1. 찹쌀 3컵 (3인분 되는 양)을 깨끗한 물에 씻은 뒤 1시간 정도 불려주세요.$' + \
        '2. 대추 15알도 물에 불려 먼지를 제거 해 주세요.$' + \
        '3. 호두 1/2컵은 손으로 잘게 잘라 주세요 건포도 1/2컵과 계피가루도 1ts 준비합니다.$' + \
        '4. 밤 7톨은 잘라서 준비해주세요.$' + \
        '5. 대추 10알은 돌려 깍기 한 뒤 채썰어주세요. 5알은 듬성 듬성 잘라주세요.$' + \
        '6. 냄비에 생수를 붓고 듬성 듬성 자른 대추와 대추씨를 넣고 끓여주세요.$' + \
        '7. 대추를 우려낸 물을 걸러주세요.$' + \
        '8. 불려 놓은 찹쌀은 체에 받혀 물기를 제거해 밥솥에 담아주세요. 그 다음 흑설탕 140g을 넣어주세요.$' + \
        '9. 간장 6Ts, 꿀 2Ts, 계피가루 1ts을 넣어주고 참기름 4Ts을 넣은 뒤 소금도 살짝 넣어주세요.$' + \
        '10. 이제 잘라 놓은 밤과 호두 채썰어 놓은 대추와 건포도까지 모두 넣어주세요$' + \
        '11. 대추 달인 물을 체에 걸러 주고 생수를 부어 350ml로 맞춰주세요.$' + \
        '12. 재료들이 잘 섞이도록 저어 준 뒤 잡곡 모드에서 40분 동안 밥을 지어주면 완성이랍니다.$'
recipeTime = '2시간'
difficulty = 'hard'
Classification = '곡류'
method = '찜'

# %%
recipeName = '간장기름떡볶이'
filename = '75.jpg'
process = '1. 떡은 끓는물에 한번 데쳐 준비한다.$' + \
        '2. 그 사이 대파를 송송 썬다.$' + \
        '3. 떡에 송송썬 대파와 양념재료를 넣어 섞는다.$' + \
        '4. 팬에 식용유, 떡을 넣고 볶아 완성한다.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '곡류'
method = '조림'

# %%
recipeName = '치즈누렁지'
filename = '76.jpg'
process = '1. 비닐봉지에 김을 넣고 손으로 비벼 김가루를 만든다.$' + \
        '2. 따뜻하게 데운 밥에 김가루와 참기름, 통깨, 소금을 넣고 잘 섞어준다.$' + \
        '3. 팬에 기름을 두르고 닦아낸 뒤 밥을 평평하게 깔아 누룽지를 만든다.$' + \
        '4. 치즈를 고루 뿌린 뒤 뚜껑으로 덮어 녹인다.$' + \
        '5. 치즈가 녹으면 반으로 접고 살짝 식힌 뒤 먹기 좋은 크기로 잘라 마무리 한다.$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '곡류'
method = '굽기'

# %%
recipeName = '햄주먹밥'
filename = '77.jpg'
process = '1. 햄은 통에서 빼서 준비하고 밥은 퍼놔주시고 김은 비닐에 넣고 부셔주세요.$' + \
        '2. 밥에 간장 3큰술, 참기름 2큰술 깨소금 2큰술을 넣고 비벼주세요.$' + \
        '3. 햄은 듬성듬성 다져주시고 볶듯이 구워주세요.$' + \
        '4. 햄을 밥에 넣고 슥슥 비벼주세요.$' + \
        '5. 밥은 동글동글하게 만들어서 김가루에 묻혀주세요.$' 
recipeTime = '20분'
difficulty = 'easy'
Classification = '육류'
method = '비빔'

# %%
recipeName = '치즈웨지감자'
filename = '78.jpg'
process = '1. 감자를 2등분으로 썬 다음 3~4조각의 웨지가 나오도록 썹니다.$' + \
        '2. 물에 10분 정도 담구어 두었다가 키친타월에 대강 물기를 닦아 줍니다.$' + \
        '3. 팬에 버터 10g, 기름 2큰술을 두르고 감자를 놓습니다. 버터 없으시면 기름을 한큰술 더 넣어 주세요.$' + \
        '4. 뚜껑 닫고 한면을 익힙니다. 한쪽면이 다 익으면 다른쪽 면도 익힌다음 감자 등쪽도 마저 익혀 주세요.$' + \
        '5. 이제 부터는 소스를 만들어 볼까 합니다. 팬에 기름을 두른 후 다진마늘 1.5큰술을 넣고 볶습니다.$' + \
        '6. 마늘 향이 코끝을 찌르면 우유를 넣고 끓어 오르면 치즈를 넣고 졸여 줍니다.$' + \
        '7. 웨지감자를 놓은 후 소스를 주르르 부어 주세요.$'
recipeTime = '60분'
difficulty = 'normal'
Classification = '유제품'
method = '굽기'

# %%
recipeName = '치즈토스트'
filename = '79.jpg'
process = '1. 먼저 버터 1스푼에 파슬리가루 약간 넣고 전자렌지에 10초 돌려 잘 섞어줍니다.$' + \
        '2. 버터소스를 식빵 한쪽면에만 발라 주세요.$' + \
        '3. 에어프라이어에 종이호일을 한장 깔고 식빵 1장을 올려주시는데요. 이때 버터 바른쪽이 밑으로 가게 놓아줍니다.$' + \
        '4. 식빵 위에 슬라이스 치즈 한장 올리고 모짜렐라 치즈를 가득 올립니다.$' + \
        '5. 다시 슬라이스 치즈 한장을 올려주시고 남은 식빵으로 덮어 주셔요. 이때는 버터 바른쪽이 윗면으로 오게 해주심 됩니다.$' + \
        '6. 에어프라이어에서 온도 170도에 5분 먼저 돌려주세요.$' + \
        '7. 식빵을 반대로 뒤집으셔서 다시 170도에 3분구워주심 끝!$'
recipeTime = '15분'
difficulty = 'easy'
Classification = '유제품'
method = '굽기'

# %%
recipeName = '계란두부전'
filename = '80.jpg'
process = '1. 두부 적당량과 계란하나를 그릇에 담는다.$' + \
        '2. 포크로 계란도 풀고 두부도 풀어줍니다.$' + \
        '3. 후라이팬에 들기름을 두르고 으깬두부와 계란을 바삭바삭 익혀줍니다.$' + \
        '4. 두부가 어느정도 익으면 찢어지지않고 뒤집을 수 있어요.$' + \
        '5. 토마토도 하나 썰어 두부굽고난 후라이팬에 익혀줍니다.$' + \
        '6. 그릇에 담아 올리브유를 살짝 뿌려서 먹으면 되요.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '채소류'
method = '굽기'

# %%
recipeName = '햄치즈전'
filename = '81.jpg'
process = '1. 치즈는 가늘게 썰고, 햄은 먹기좋게 썰고, 대파는 송송썰어 주세요.$' + \
        '2. 달걀은 풀어 주세요.$' + \
        '3. 팬에 식용유를 두르고 햄과 대파를 넣고 볶아 주세요.$' + \
        '4. 둥글게 모아 주세요. 그 위에 달걀물을 부어 주세요.$' + \
        '5. 치즈를 올려 준 후 뚜껑을 닫고 익혀 주세요.$' + \
        '6. 파슬리 가루를 뿌려주세요.$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '육류'
method = '부침'

# %%
recipeName = '버섯볶음밥'
filename = '82.jpg'
process = '1. 볶음밥에 넣을 재료인 대파,햄,새송이버섯을 썰어주세요. 새송이버섯은 길게 말고 동글게 썰어주는게 식감이 더 좋아요.$' + \
        '2. 팬에 식용유를 두르고 대파를 볶아 파기름을 만들어 줘요.$' + \
        '3. 파향이 올라오면서 파가 노르스름하게 익으면 햄,새송이버섯을 넣고 볶아요.$' + \
        '4. 밥 1.5 공기를 넣고 간장 또는 굴소스를 간을 해줍니다.$' + \
        '5. 마지막에 통깨,후춧가루를 넣어 마무리 해주세요.$' 
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '볶음'

# %%
recipeName = '삼계탕'
filename = '83.jpg'
process = '1. 먼저 닭을 깨끗이 씻은 후 꽁지부분을 제거해주세요. 30분정도 미리 불려놓은 쌀을 닭 안에 채워 줍니다.$' + \
        '2. 다리를 겹치게 꼬아준 후 이쑤시개로 고정시켜 주세요.한쪽 닭다리에 칼집을 내어 다른쪽을 꼬아 넣어주셔도 됩니다.$' + \
        '3. 압력밥솥에 물 2000ml정도와 한방팩, 대추, 마늘, 닭을 넣어줍니다.$' + \
        '4. 뚜껑을 잘 닫은 뒤 센불에서 끓여 주시다가 추가 움직이기 시작하면 중불로 낮춰 10분간 삶아주고 바로 김을 빼줍니다.$' + \
        '5. 준비해두었던 전복과 후추, 소금을 약간 넣고 같은방법으로 10분 더 끓여줍니다.$' + \
        '6. 다 끓여지면 대파를 넣어 주시고 소금으로 간을 맞춰 드시면 되는데요.이제 닭육수가 준비됬으니 양념장을 만들어 봅시다.$' + \
        '7. 닭육수1/4컵+고춧가루1/4컵+겨자조금+간장2T+식초2T+설탕1/3T+다진마늘1T+대파 약간을 잘 섞어주세요.$'
recipeTime = '30분'
difficulty = 'hard'
Classification = '육류'
method = '끓이기'

# %%
recipeName = '갈치조림'
filename = '84.jpg'
process = '1. 감자는 조금 두툼하게 썰고 양파, 청양초, 대파는 먹기 좋게 썰어둔다.$' + \
        '2. 손질해 온 갈치도 깨끗하게 씻어둔다.$' + \
        '3. 냄비에 물 1컵을 붓고 감자를 먼저 삶아준다.$' + \
        '4. 고추장, 고춧가루, 마늘, 매실엑기스를 넣고 함께 섞어 양념장을 만들어 준다.$' + \
        '5. 감자가 반쯤 익으면 갈치와 양념장을 올려준다.$' + \
        '6. 갈치가 익으면 썰어둔 채소를 넣어 마무리한다.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '조림'

# %%
recipeName = '양송이크림리조또'
filename = '85.jpg'
process = '1. 양송이, 양파, 슬라이스 햄을 썰어주시고 땡초는 씨를 제거하고 다져주세요.$' + \
        '2. 위 준비한 재료 팬에 담고 소금 1꼬집, 후추 넣고 버터 조금 넣고 슥슥 볶아주세요.$' + \
        '3. 볶아 주신후 우유 종이컵1컵 생크림 소주컵 반컵 붓고 끓어 오르면 밥을 넣어주세요.$' + \
        '4. 모짜렐라 치즈, 슬라이스 치즈, 크림치즈파스타소스, 파마산치즈가루 조금 넣고 저어가면서 걸쭉하게 끓이세요.$' + \
        '5. 적당히 졸여지면 완성!$'
recipeTime = '15분'
difficulty = 'normal'
Classification = '육류'
method = '끓이기'

# %%
recipeName = '돼지고기냉채'
filename = '86.jpg'
process = '1. 냄비에 물을 붓고 대파, 양파, 마늘, 생강, 월계수잎, 통후추, 소주, 된장, 간장, 통후추, 계핏가루, 정향를 넣고 약 20분간 끓인 후 돼지고기를 넣어 주세요.$' + \
        '2. 고기를 넣고 대략 40분 정도 삶으시면 됩니다.$' + \
        '3. 잘 삶아진 돼지고기는 한 김 나간 후 얇게 썰어 주세요.$' + \
        '4. 설탕, 다진마늘, 식초, 소금, 양조간장, 연겨자를 넣고 냉채 소스를 만들어 냉장고에서 차게 보관해 주세요.$' + \
        '5. 칵테일 새우는 끓는 물에 살짝 데쳐서 준비해 주시고 달걀은 지단을 부쳐 주세요.$' + \
        '6. 달걀 지단은 달군 팬에 식용유를 두르고 키친타올로 살짝 닦은 후 달걀물을 펴 주신 후 약불로 줄여 주세요.$' + \
        '7. 달걀물을 붓고 겉면이 익기 시작하면 뒤집은 후 불을 꺼 주세요. 팬에 남아 있는 열로 익힌 후 3-4cm 길이로 채썰어 주세요.$' + \
        '8. 오이는 반으로 자른 후 어슷썰기 해 주시고 양파는 가늘게 채 썰어 주세요.$' + \
        '9. 복숭아는 껍질을 벗긴 후 씨를 제거하고 얇게 슬라이스 해 주세요.$' + \
        '10. 게맛살은 가늘게 찢어 주세요. 준비된 재료는 냉장고에서 차게 보관해 주세요.$' + \
        '11. 먹기 직전에 접시에 손질한 재료를 가지런히 담아 주세요.$' 
recipeTime = '2시간'
difficulty = 'hard'
Classification = '육류'
method = '삶기'

# %%
recipeName = '소고기 버섯매운탕'
filename = '87.jpg'
process = '1. 쌀뜬물 7컵에 멸치, 다시마 등과 소고기를 넣고 약 15분정도 육수를 내주시고 다시마팩은 건져줍니다.$' + \
        '2. 무는 납작하게 썰어주고 느타리와 팽이는 결대로 쪽쪽 찢어주고, 새송이와 표고는 먹기좋은 크기로 썰어주세요.$' + \
        '3. 미나리는 6cm 정도로, 대파는 어슷 썰어서 준비합니다.$' + \
        '4. 분량의 양념 재료를 모두 넣고 골고루 섞어주세요. 새우젓이 들어가야 국물이 시원하니 감칠맛이 좋아요.$' + \
        '5. 육수에 무를 넣고 끓여주다가 설컹거릴정도로 익으면 버섯과 양파를 넣고, 양념을 넣어 끓여주세요.$' + \
        '6. 버섯은 너무 오래 끓이면 버섯향이 날아가서 맛이 없으니 살짝 익을 정도로만 끓여주시면 되요.$' + \
        '7. 생기는 거품은 걷어 주시고, 부족한 간은 소금으로 하시고 기호에 맞게 고추가루 양은 가감하세요.$' + \
        '8. 다 익으면 미나리, 고추 팽이버섯을 올리고 한소끔만 더 끓여주시면 된답니다.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '육류'
method = '끓이기'

# %%
recipeName = '바나나팬케이크'
filename = '88.jpg'
process = '1. 볼에 계란을 넣고 저어 풀어줍니다.$' + \
        '2. 계란에 바나나를 넣어서 포크로 덩어리가 보이지 않게 으깨줍니다.$' + \
        '3. 완성된 반죽을 팬에 기름을 살짝만 두르고 손바닥 정도의 크기로 동그랗게 모양을 만들어 줍니다.$' + \
        '4. 계란 반죽이라 잘 익기 때문에 너무 오래 두면 탈 수 있으니 약불에 구워주면 완성입니다.$' 
recipeTime = '10분'
difficulty = 'easy'
Classification = '유제품'
method = '부침'

# %%
recipeName = '오코노미야끼'
filename = '89.jpg'
process = '1. 오징어는 채썬후, 다시 토막토막 1~2센티 정도로 잘라주시고, 새우도 식감있는 정도로 3,4등분 해주세요.$' + \
        '2. 양배추와 양파는 채썰어서 너무 야채 길이가 길거나 크지않을정도로만 잘라 준비해주세요.$' + \
        '3. 마요네즈와 야끼소바소스를 준비해주세요. 만약 오코노미야끼용 소스가 없다면 돈까스 소스나 오므라이스 소스도 괜찮아요.$' + \
        '4. 큰 볼에 양배추, 양파, 해산물을 넣고, 계란두개와 부침가루 2~3큰술을 넣은 후 질어질 때까지 섞어주세요.$' + \
        '5. 집에 다진마늘 있으시면 1t정도 넣으시고, 후춧가루도 약간 뿌려주고 섞어주세요.$' + \
        '6. 후라이팬을 중불로 달궈서 오일을 넉넉히 넣고, 불은 약불로 줄여주신후 반죽을 동그랗게 다듬으면서 두툼하게 올려주세요.$' + \
        '7. 손바닥보다 약간 큰 정도면 뒤집기 편해요. 불이 강하면 겉만 타고 안은 안익으니 약불로 뚜껑을 덮고 조리해주세요.$' + \
        '8. 약불에 지지다가 뚜껑을 덮고 1분정도 뭉근히 구워주세요. 그리고 아래면이 익으면 상태를 봐서 한방에 뒤집어주세요.$' + \
        '9. 접시에 담아주시고 마요네즈를 넓게 펴서 발라주세요.$' + \
        '10. 야끼소바 소스를 지그재그로 뿌려주세요. 만약 소스가 없다면 돈까스 소스나 오므라이스 소스도 괜찮아요.$' + \
        '11. 마지막으로 가츠오부시를 위에 넉넉하게 뿌려 덮어주세요. 없다면 생략해도 되요.$'
recipeTime = '15분'
difficulty = 'normal'
Classification = '해산물'
method = '부침'

# %%
recipeName = '아귀찜'
filename = '90.jpg'
process = '1. 분량의 양념 재료를 모두 넣고 섞어주세요.$' + \
        '2. 아귀를 물에 깨끗하게 씻은 후, 아귀가 잠길 정도로 물을 부어주세요. 그 다음 맛술 미림을 부어 아귀의 비린내를 제거해주세요.$' + \
        '3. 된장 1큰술을 넣고 아귀를 삶은 후, 물을 버리고 아귀를 꺼내서 준비해주세요.$' + \
        '4. 미나리는 잎을 제외하고 먹기 좋게 썰어주세요. 고추와 대파는 어슷썰기, 양파는 굵게 채썰기를 하여 아귀찜에 들어갈 채소를 준비해주세요.$' + \
        '5. 미리 삶아놓은 아귀와 미더덕, 양념장, 멸치 다시마 육수 1컵을 넣고 센 불에서 볶으면서 양념이 잘 섞이도록 해주세요.$' + \
        '6. 양념이 어느 정도 배면 콩나물을 넣고 한 번 더 볶아주세요.$' + \
        '7. 콩나물 숨이 죽으면 미리 손질해놓은 남은 채소들도 넣어주세요.$' + \
        '8. 아귀찜이 전체적으로 익으면 전분물로 걸쭉하게 농도를 맞춰주세요.$'
recipeTime = '60분'
difficulty = 'hard'
Classification = '해산물'
method = '찜'

# %%
recipeName = '시래기표고버섯밥'
filename = '91.jpg'
process = '1. 마른표고버섯은 물에 불려 부드럽게 만들어 줍니다.$' + \
        '2. 불린표고버섯은 건져내고 표고버섯 우린물을 버리지말고 두세요. 밥물로 사용합니다.$' + \
        '3. 쌀을 조금 불려주셔야해요. 쌀은 깨끗이 씻은후 1시간정도 불렸다가 체에 받쳐 물기를 쏙 빼줍니다.$' + \
        '4. 삶은 시래기는 1센티 정도 길이로 쫑쫑 썰어준 후 시래기양념 재료를 모두 넣고 손으로 조물조물 버무려둡니다.$' + \
        '5. 밥은 압력밥솥에다 할거에요. 압력밥솥 안에 들기름을 한숟갈 넣어준 후 양념한 시래기와 표고버섯을 넣고 달달 볶아줍니다.$' + \
        '6. 불린쌀도 넣고 달달 볶아주세요.$' + \
        '7. 물은 준비해둔 표고버섯물을 넣어 밥물을 잡아줍니다.$' + \
        '8. 가스불에 올려 일반 밥짓듯이 압력솥밥을 지으면 됩니다.$'
recipeTime = '90분'
difficulty = 'normal'
Classification = '곡류'
method = '찜'

# %%
recipeName = '월남쌈'
filename = '92.jpg'
process = '1. 파프리카는 깨끗하게 씻어 물기를 제거한 후 4cm 길이로 잘라주세요. 적채와 당근, 깻잎은 채를 썰어주세요.$' + \
        '2. 양파는 채를 썰어주신 후 찬물에 담가 매운기를 없애주세요.$' + \
        '3. 무순과 새싹채소는 흐르는 물에 부드럽게 씻은 후 물기를 제거해주세요.$' + \
        '4. 달걀은 풀어서 기름을 살짝 두른 팬에 얇게 부친 후 4cm 길이로 채썰어 주세요.$' + \
        '5. 파인애플은 3cm 크기로, 영양부추는 4cm 길이로 잘라주세요.$' + \
        '6. 새우는 끓는 물에 살짝 데쳐주세요.$' + \
        '7. 큰 접시에 손질 한 재료를 둘러 담고 소스를 따로 준비해 주세요.$' + \
        '8. 큰 볼에 따뜻한 물을 준비해주세요. 라이스페이퍼를 따뜻한 물에 담가 살짝 적신 후 각종 채소와 새우를 넣고 싸주세요.$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '해산물'
method = '데치기'

# %%
recipeName = '가지나물무침'
filename = '93.jpg'
process = '1. 가지는 씻어서 꼭지를따주세요.$' + \
        '2. 가지는 적당한 크기로 잘라 찜기에 넣어주세요.$' + \
        '3. 젖가락으로 찔러서 가지가 잘 들어가면 불을 끄고 식혀주세요.$' + \
        '4. 가지를 먹기 편하게 찢어서 꼭 짜서 물기를 빼주세요.$' + \
        '5. 다진마늘, 국간장, 소금, 들기름, 갈은깨로 무쳐주세요.$' + \
        '6. 간을 보고 마지막에 참기름을 1티스푼 넣고 한번 더 무치면 가지나물 완성!$' 
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '무침'

# %%
recipeName = '훈제오리 부추무침'
filename = '94.jpg'
process = '1. 양파1/2개를 채썰어서 준비합니다.$' + \
        '2. 부추는 흐르는 물에 깨끗하게 씻은 뿌리 부분쪽을 1cm정도 잘라준뒤 5cm간격으로 잘라줍니다.$' + \
        '3. 큰 볼에 양파와 부추를 담아줍니다.$' + \
        '4. 여기에 설탕1/2스푼,참기름2스푼,고추가루1스푼,마늘1스푼,식초1.5스푼,액젓2스푼을 넣어줍니다.$' + \
        '5. 부추와 양파 그리고 양념이 잘섞이도록 조물조물 해줍니다.$' + \
        '6. 오리를 기름을 두루지 않은 후라이팬에 넣고 구워줍니다.$' + \
        '7. 오리는 키친타올에 올려 기름을 제거해주세요$' + \
        '8. 넓은 접시에 부추를 깔고 그 위에 오리를 올리면 완성!$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '육류'
method = '무침'

# %%
recipeName = '깐풍기'
filename = '95.jpg'
process = '1. 닭다리살을 한입크기로 썰어준 뒤 후추를 약간 뿌리고 진간장2숟갈을 넣은뒤 섞어주고 10분간 재운다.$' + \
        '2. 재우는동안 불린전분100g을 만든 후 계란 흰자와 불린전분을 같이 닭다리살에 넣고 섞어준다.$' + \
        '3. 끓는 기름에 반죽한 닭다리살을 넣고 튀겨주며 중간에 1~2번 채로 건져내서 찬바람을 쐬어준다.$' + \
        '4. 튀기는동안 양념소스(닭육수4스푼, 진간장2스푼, 굴소스1스푼, 설탕4스푼, 식초4스푼 , 후추약간)을 넣고 섞어 만들어준다.$' + \
        '5. 팬에 고추기름3스푼, 다진 대파1/2대, 다진마늘1스푼, 다진생강1/3스푼을 넣고 약불에 살짝 섞어가면 볶아준다.$' + \
        '6. 잘 섞이면 맛술1스푼과 진간장1스푼을 추가로 넣어주고 미리 다져놓은 홍고추, 청고추 1알씩 넣고 건고추 5알을 넣는다.$' + \
        '7. 그 후 준비된 양념을 넣고 약불에 섞어준다.$' + \
        '8. 센 불에 양념이 잘 섞이면 튀겨두었던 닭다리살튀김을 넣고 볶아준다. 양념이 다 베이고 완성되기 20초 전에 참기름 1스푼을 둘러준다.$'
recipeTime = '30분'
difficulty = 'hard'
Classification = '육류'
method = '튀김'

# %%
recipeName = '양파튀김'
filename = '96.jpg'
process = '1. 먼저 양파는 약간 두께감 있게 링모양으로 잘라 주신 뒤 한겹씩 떼어 놓고 볼에 담아 물을 약간씩 뿌려 겉에 물기를 뭍혀 줍니다.$' + \
        '2. 계란과 우유를 1:1 비율로 넣고 섞어 계란물을 만듭니다.$' + \
        '3. 위생비닐에 양파를 넣고 카레가루와 고춧가루를 섞은 가루를 넣어줍니다.$' + \
        '4. 봉지를 살짝 부풀려 가루가 골고루 묻도록 잘 섞어 줍니다.$' + \
        '5. 가루가 잘 묻어나면 이번에는 튀김가루를 넣고 또 한번 열심히 흔들어 줍니다.$' + \
        '6. 계란물-빵가루 순으로 묻혀줍니다.$' + \
        '7. 달궈진 기름에 노릇노릇하게 튀겨 주세요.$' + \
        '8. 양파는 금방 익기 때문에 빵가루가 노릇노릇 해지면 타지 않게 건져 내 주시고 키친타올에 올려 기름기를 빼주면 완성!$'
recipeTime = '30분'
difficulty = 'normal'
Classification = '채소류'
method = '튀김'

# %%
recipeName = '버섯야채죽'
filename = '97.jpg'
process = '1. 재료를 깨끗이 씻어서 준비해주세요.$' + \
        '2. 모든 재료는 그리 크지않게 곱게 다져놔주세요.$' + \
        '3. 표고버섯은 생것보다 말려걸 불린걸 쓰는게 향이 좋치만 없으시다면 그냥 있는 재료내에서 준비해주세요.$' + \
        '4. 불린쌀(1/2컵)을 쌀알갱이가 반정도 싸이즈가 되게 빻아주세요$' + \
        '5. 참기름을 두르고 위에 준비해놓은 불린쌀과 당근, 표고, 새송이, 호박을 넣고 약 2~3분간 볶아주세요.$' + \
        '6. 이제 물(3컵)을 붓고 거품을 제거해가며 쌀알이 익을때까지 중약불에서 약 20분간 저어가며 끓여주세요.$' + \
        '7. 거의다 끓였을때쯤 소금이나 국간장으로 기호에 맞춰서 간을 해주세요.$'
recipeTime = '60분'
difficulty = 'normal'
Classification = '곡류'
method = '끓이기'

# %%
recipeName = '마약토스트'
filename = '98.jpg'
process = '1. 먼저 햄을 먹기 좋게 잘라주시고 계란1개를 깨서 흰자와 노른자를 분리해줍니다.$' + \
        '2. 전자렌지가능한 용기에 식빵을 담고 마요네즈를 식빵 둘레에 돌려가며 짜 주세요.$' + \
        '3. 그 다음 계란흰자와 햄을 넣고 전자렌지에 약 1분 돌려 줍니다.$' + \
        '4. 이제 계란 노른자를 올리고 그 위에 모짜렐라 치즈,후추를 뿌리고 다시 1분 정도 돌려주시면 끝!$'
recipeTime = '10분'
difficulty = 'easy'
Classification = '유제품'
method = '굽기'

# %%
recipeName = '수플레오믈렛'
filename = '99.jpg'
process = '1. 계란 흰자 노른자 분리하고 노른자에 꽃소금 1~2꼬집 넣고$' + \
        '2. 흰자에 설탕 1스푼 넣고 거품기로 거품 낸다. 수동으로 하는 경우 많이 저어 거품을 낸다$' + \
        '3. 거품낸 흰자 절반을 노른자에 넣고 골고루 섞는다. $' + \
        '4. 약불에 달궈진 팬에 식용유 약간 넣고 골고루 코팅한다.$' + \
        '5. 그 위에노른자를 넣고 둥근 모양을 만들고 위에 흰자 거품 올리고 평평하게 한다.$' + \
        '6. 뚜껑 덮고 꺼질락 말락 하는 정도의 불에 놓고 4~5분간 익힌다.$' + \
        '7. 4분 후 버터를 가장 자리에 넣고 버터가 아래에 스며 들도록 한다.$' + \
        '8. 반으로 접어 모양을 잡아 주면 반달 모양으로 만든다.$' + \
        '9. 접시에 놓고 메이플시럽을 뿌려주면 완성된다. 꿀을 뿌려도 좋다.$'
recipeTime = '15분'
difficulty = 'hard'
Classification = '유제품'
method = '굽기'

# %%
recipeName = '고구마사과샐러드'
filename = '100.jpg'
process = '1. 고구마는 껍질을 벗겨주세요. 한입 크기정도로 썰어주세요.$' + \
        '2. 사과 반개는 1센치 크기 정도로 썰어주세요.$' + \
        '3. 냄비에 미리 물을 끓여주시구요. 물이 끓기 시작하면 썰어놓은 고구마를 넣고 10분정도 삶아주세요.$' + \
        '4. 삶아진 고구마는 물기를 제거하고 포크를 이용해서 으깨 주세요.$' + \
        '5. 으깬 고구마에 잘라놓은 사과를 넣고, 플레인 요거트를 넣어서 섞어주세요.$' + \
        '6. 견과류를 조금 넣어주고, 저는 블루베리를 조금 섞어주었어요. 과일은 선택입니다.$' + \
        '7. 꿀을 한스푼 넣어주시면 더 맛있죠. 완성!$'
recipeTime = '30분'
difficulty = 'easy'
Classification = '채소류'
method = '삶기'

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from PIL import Image
import base64
from io import BytesIO

engine = create_engine('mysql+pymysql://hello:Csedbadmin!1@13.125.102.154/pytest', echo = False)
buffer = BytesIO()
im = Image.open(filename)

im.save(buffer, format='jpeg')
data = base64.b64encode(buffer.getvalue())

img_df = pd.DataFrame({'recipeName':[recipeName], 'data':[data], 'process':[process], 'recipeTime':[recipeTime],
                       'difficulty':[difficulty], 'Classification':[Classification], 'method':[method]})
img_df.to_sql('recipe', con=engine, if_exists='append', index=False)

# %%
engine = create_engine('mysql+pymysql://hello:Csedbadmin!1@13.125.102.154/pytest', echo = False)

img_df2 = pd.read_sql(sql="select * from recipe where recipeName = '" + recipeName + "'", con=engine)
img_str = img_df2['data'].values[0]

img = base64.decodebytes(img_str)
im = Image.open(BytesIO(img))
im.show()
